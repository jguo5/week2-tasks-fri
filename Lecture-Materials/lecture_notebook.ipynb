# %% [markdown]
# # Selenium Tutorial - Lecture Version
#
# This tutorial is accompanying the lecture slides for "Getting data from the Web (Part 2).
#
# **Author**: Eni Mustafaraj
# **Created on:** Sep 10, 2026
#
# **Table of Contents**
#
# 1. [Using `requests` and `BeautifulSoup`](#sec1)
# 2. [Simple use of `seleniumbase`](#sec2)
# 3. [Clicking button with `seleniumbase`](#sec3)
# 4. [Scrolling with `seleniumbase`](#sec4)
# 5. [Your task: Simple parser](#sec5)
# 6. [Handling pagination](#sec6)
# 7. [Your task: Modify parser for mockup page](#sec7)

# %% [markdown]
# <h2 id="sec1">1. Using <em>requests</em> and <em>BeautifulSoup</em></h2>
#
# We will first try to get the content of both our pages using the two libraries we already know.

# %%
import requests
from bs4 import BeautifulSoup

BASE_URL = "https://cs.wellesley.edu/~cs315/scraping"

# %% [markdown]
# We'll write a function that retrieves the pages, given the URL.

# %%
def fetch_page_content(url):
    """Fetches HTML content from a URL and checks status code."""
    response = requests.get(url)

    print(f"URL: {url}")
    print(f"Status Code: {response.status_code}")

    if response.status_code == 200:
        return response.text
    else:
        print(f"Failed to fetch page. Status code: {response.status_code}")
        return None

# %% [markdown]
# Let's test that the function works as intended:

# %%
url = f"{BASE_URL}/page1.html"
page = fetch_page_content(url)
print(page)
# Out:
# URL: https://cs.wellesley.edu/~cs315/scraping/page1.html
# Status Code: 200
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <title>Data Page V1</title>
#     <style>
#         table, th, td {
#             border: 1px solid black;
#             border-collapse: collapse;
#             padding: 8px; }
#         th { background-color: #f2f2f2; }
#     </style>
# </head>
# <body>
#     <h1>Student Grades V1</h1>
#     <table id="grades-table">
#         <thead>
#             <tr>
#                 <th>Student ID</th>
#                 <th>Name</th>
#                 <th>Grade</th>
#             </tr>
#         </thead>
#         <tbody>
#             <tr>
#                 <td>101</td>
#                 <td>Alice Johnson</td>
#                 <td>A</td>
#             </tr>
#             <tr>
#                 <td>102</td>
#                 <td>Bob Smith</td>
#                 <td>B</td>
#             </tr>
#             <tr>
#                 <td>103</td>
#                 <td>Charlie Brown</td>
#                 <td>A-</td>
#             </tr>
#         </tbody>
#     </table>
# </body>
# </html>

# %% [markdown]
# And now let's write a function that will extract the values of the table:

# %%
def parse_table(html_content):
    """Parses HTML content and returns table rows as a list of tuples."""
    if not html_content:
        return []

    soup = BeautifulSoup(html_content, "html.parser")
    rows = soup.find_all("tr")

    table_data = []
    for row in rows:
        cells = [cell.get_text(strip=True) for cell in row.find_all(["th", "td"])] #table header or table data
        if cells:
            table_data.append(tuple(cells)) #append to list

    return table_data

# %% [markdown]
# Now let's test this function with the output of the `fetch_page_content`:

# %%
parse_table(page)
#alternatively can save as csv file
# Out:
# [('Student ID', 'Name', 'Grade'),
#  ('101', 'Alice Johnson', 'A'),
#  ('102', 'Bob Smith', 'B'),
#  ('103', 'Charlie Brown', 'A-')]

# %% [markdown]
# Let's now try these two functions with the dynamic page:

# %%
url = f"{BASE_URL}/page2.html"
page = fetch_page_content(url)
print(page)
parse_table(page)
# Out:
# URL: https://cs.wellesley.edu/~cs315/scraping/page2.html
# Status Code: 200
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <title>Data Page V2</title>
#     <style>
#         table, th, td {
#             border: 1px solid black;
#             border-collapse: collapse;
#             padding: 8px; }
#         th { background-color: #e2e2e2; }
#     </style>
# </head>
# <body>
#     <h1>Student Grades V2</h1>
#
#     <div id="table-container"></div>
#
#     <script src="data.js"></script>
# </body>
# </html>
# []

# %% [markdown]
# **Conclusion:** For the 2nd page, where the table is injected with JS, our code didn't return any rows. In order to get the entire content of the page, we will use Selenium, which opens a broswer and creates the DOM.

# %% [markdown]
# <h2 id="sec2">2. Simple use of <em>seleniumbase</em></h2>
#
# Seleniumbase is a framework built on top of standard Selenium. It does everything that Selenium does but in a better way and with less overhead.
#
# First, let's open the URL on the browser, load the page, then save the rendered content:

# %%
from seleniumbase import Driver

url = f"{BASE_URL}/page2.html"

with Driver() as driver:
    driver.open(url)
    # this line is here to make sure the table is created before we save the page
    driver.wait_for_element("#grades-table") 
    driver.sleep(5) # sleep so that we can see the browser
    rendered_html = driver.get_page_source()

# %% [markdown]
# Now that we have the rendered HTML, we can use the function from above to parse the HTML.

# %%
data = parse_table(rendered_html)

print(f"Extracted {len(data)} rows:")
for row in data:
    print(row)
# Out:
# Extracted 4 rows:
# ('Student ID', 'Name', 'Grade')
# ('201', 'Diana Prince', 'A+')
# ('202', 'Evan Wright', 'B+')
# ('203', 'Fiona Gallagher', 'A')

# %%
print(rendered_html)
# Out:
# <html lang="en"><head>
#     <meta charset="UTF-8">
#     <title>Data Page V2</title>
#     <style>
#         table, th, td {
#             border: 1px solid black;
#             border-collapse: collapse;
#             padding: 8px; }
#         th { background-color: #e2e2e2; }
#     </style>
# </head>
# <body>
#     <h1>Student Grades V2</h1>
#
#     <div id="table-container">
#         <table id="grades-table">
#             <thead>
#                 <tr>
#                     <th>Student ID</th>
#                     <th>Name</th>
#                     <th>Grade</th>
#                 </tr>
#             </thead>
#             <tbody>
#
#             <tr>
#                 <td>201</td>
#                 <td>Diana Prince</td>
#                 <td>A+</td>
#             </tr>
#
#             <tr>
#                 <td>202</td>
#                 <td>Evan Wright</td>
#                 <td>B+</td>
#             </tr>
#
#             <tr>
#                 <td>203</td>
#                 <td>Fiona Gallagher</td>
#                 <td>A</td>
#             </tr>
#
#             </tbody>
#         </table>
#     </div>
#
#     <script src="data.js"></script>
#
# </body></html>

# %% [markdown]
# As we can see, through this method we were able to extract the table content from the dynamic page as well.

# %% [markdown]
# <a id="sec3"></a>
#
# ## 3. Clicking buttons with `seleniumbase`
#
# Our [new interactive page](https://cs.wellesley.edu/~cs315/scraping/page3.html) requires us to click a button a few times for all the data to appear. We'll write code to do that. But first, let's look at the HTML source code to find the button:
#
# ```
# <body>
#     <h1>Student Grades (Interactive)</h1>
#
#     <!-- Button to dynamically add more rows -->
#     <button id="add-btn">Add More Students</button>
#
#     <table id="grades-table">
#         <thead>
# ```

# %% [markdown]
# First we will see what happens if we click once:

# %%
newURL = "https://cs.wellesley.edu/~cs315/scraping/page3.html"

with Driver() as driver:
    driver.open(newURL)
    button_selector = "#add-btn" # the id attribute value for the button
    driver.sleep(2)
    driver.click(button_selector)
    driver.sleep(2)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[14], line 7
#       6 driver.sleep(2)
# ----> 7 driver.click(button_selector)
#       8 driver.sleep(2)
#
# File c:\Users\iwuba\AppData\Local\Programs\Python\Python311\Lib\site-packages\seleniumbase\core\sb_driver.py:218, in DriverMethods.click(self, *args, **kwargs)
#     217 def click(self, *args, **kwargs):
# --> 218     page_actions.click(self.driver, *args, **kwargs)
#
# File c:\Users\iwuba\AppData\Local\Programs\Python\Python311\Lib\site-packages\seleniumbase\fixtures\page_actions.py:1782, in click(driver, selector, by, timeout)
#    1781     return
# -> 1782 element = wait_for_element_clickable(
#    1783     driver, selector, by=by, timeout=timeout
#    1784 )
#    1785 element.click()
#
# File c:\Users\iwuba\AppData\Local\Programs\Python\Python311\Lib\site-packages\seleniumbase\fixtures\page_actions.py:1077, in wait_for_element_clickable(driver, selector, by, timeout, original_selector)
#    1072     message = "Element {%s} was not clickable after %s second%s!" % (
#    1073         selector,
#    1074         timeout,
#    1075         plural,
#    1076     )
# -> 1077     timeout_exception(ElementNotInteractableException, message)
#    1078 elif not element and by == "link text" and not is_visible:
#
# File c:\Users\iwuba\AppData\Local\Programs\Python\Python311\Lib\site-packages\seleniumbase\fixtures\page_actions.py:270, in timeout_exception(exception, message)
#     269 exc, msg = shared_utils.format_exc(exception, message)
# --> 270 raise exc(msg)
#
# Exception: Element {#add-btn} was not clickable after 7 seconds!
#
# During handling of the above exception, another exception occurred:
#
# TimeoutError                              Traceback (most recent call last)
# File c:\Users\iwuba\AppData\Local\Programs\Python\Python311\Lib\socket.py:836, in create_connection(address, timeout, source_address, all_errors)
#     835     sock.bind(source_address)
# --> 836 sock.connect(sa)
#     837 # Break explicitly a reference cycle
#
# TimeoutError: timed out
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 3
#       1 newURL = "https://cs.wellesley.edu/~cs315/scraping/page3.html"
# ----> 3 with Driver() as driver:
#       4     driver.open(newURL)
#       5     button_selector = "#add-btn" # the id attribute value for the button
#
# File c:\Users\iwuba\AppData\Local\Programs\Python\Python311\Lib\site-packages\selenium\webdriver\remote\webdriver.py:325, in WebDriver.__exit__(self, exc_type, exc, traceback)
#     319 def __exit__(
#     320     self,
#     321     exc_type: type[BaseException] | None,
#     322     exc: BaseException | None,
#     323     traceback: types.TracebackType | None,
#     324 ):
# --> 325     self.quit()
#
# File c:\Users\iwuba\AppData\Local\Programs\Python\Python311\Lib\site-packages\selenium\webdriver\common\webdriver.py:42, in LocalWebDriver.quit(self)
#      40 finally:
#      41     if hasattr(self, "service") and self.service is not None:
# ---> 42         self.service.stop()
#
# File c:\Users\iwuba\AppData\Local\Programs\Python\Python311\Lib\site-packages\selenium\webdriver\common\service.py:166, in Service.stop(self)
#     164 if self.process.poll() is None:
#     165     try:
# --> 166         self.send_remote_shutdown_command()
#     167     except TypeError:
#     168         pass
#
# File c:\Users\iwuba\AppData\Local\Programs\Python\Python311\Lib\site-packages\selenium\webdriver\common\service.py:151, in Service.send_remote_shutdown_command(self)
#     148     return
#     150 for _ in range(30):
# --> 151     if not self.is_connectable():
#     152         break
#     153     sleep(1)
#
# File c:\Users\iwuba\AppData\Local\Programs\Python\Python311\Lib\site-packages\selenium\webdriver\common\service.py:141, in Service.is_connectable(self)
#     133 def is_connectable(self) -> bool:
#     134     """Check if the service is ready via the W3C WebDriver /status endpoint.
#     135
#     136     This makes an HTTP request to the /status endpoint and verifies if it is ready to accept new sessions.
#    (...)    139         True if the service is ready to accept new sessions, False otherwise.
#     140     """
# --> 141     return utils.is_url_connectable(self.port)
#
# File c:\Users\iwuba\AppData\Local\Programs\Python\Python311\Lib\site-packages\selenium\webdriver\common\utils.py:156, in is_url_connectable(port, host, scheme)
#     153 opener = urllib.request.build_opener(proxy_handler)
#     155 request = urllib.request.Request(f"{scheme}://{host}:{port}/status")
# --> 156 with opener.open(request, timeout=1) as res:
#     157     if res.getcode() != 200:
#     158         return False
#
# File c:\Users\iwuba\AppData\Local\Programs\Python\Python311\Lib\urllib\request.py:519, in OpenerDirector.open(self, fullurl, data, timeout)
#     516     req = meth(req)
#     518 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 519 response = self._open(req, data)
#     521 # post-process response
#     522 meth_name = protocol+"_response"
#
# File c:\Users\iwuba\AppData\Local\Programs\Python\Python311\Lib\urllib\request.py:536, in OpenerDirector._open(self, req, data)
#     533     return result
#     535 protocol = req.type
# --> 536 result = self._call_chain(self.handle_open, protocol, protocol +
#     537                           '_open', req)
#     538 if result:
#     539     return result
#
# File c:\Users\iwuba\AppData\Local\Programs\Python\Python311\Lib\urllib\request.py:496, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     494 for handler in handlers:
#     495     func = getattr(handler, meth_name)
# --> 496     result = func(*args)
#     497     if result is not None:
#     498         return result
#
# File c:\Users\iwuba\AppData\Local\Programs\Python\Python311\Lib\urllib\request.py:1377, in HTTPHandler.http_open(self, req)
#    1376 def http_open(self, req):
# -> 1377     return self.do_open(http.client.HTTPConnection, req)
#
# File c:\Users\iwuba\AppData\Local\Programs\Python\Python311\Lib\urllib\request.py:1348, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1346 try:
#    1347     try:
# -> 1348         h.request(req.get_method(), req.selector, req.data, headers,
#    1349                   encode_chunked=req.has_header('Transfer-encoding'))
#    1350     except OSError as err: # timeout error
#    1351         raise URLError(err)
#
# File c:\Users\iwuba\AppData\Local\Programs\Python\Python311\Lib\http\client.py:1298, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1295 def request(self, method, url, body=None, headers={}, *,
#    1296             encode_chunked=False):
#    1297     """Send a complete request to the server."""
# -> 1298     self._send_request(method, url, body, headers, encode_chunked)
#
# File c:\Users\iwuba\AppData\Local\Programs\Python\Python311\Lib\http\client.py:1344, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1340 if isinstance(body, str):
#    1341     # RFC 2616 Section 3.7.1 says that text default has a
#    1342     # default charset of iso-8859-1.
#    1343     body = _encode(body, 'body')
# -> 1344 self.endheaders(body, encode_chunked=encode_chunked)
#
# File c:\Users\iwuba\AppData\Local\Programs\Python\Python311\Lib\http\client.py:1293, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1291 else:
#    1292     raise CannotSendHeader()
# -> 1293 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File c:\Users\iwuba\AppData\Local\Programs\Python\Python311\Lib\http\client.py:1052, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1050 msg = b"\r\n".join(self._buffer)
#    1051 del self._buffer[:]
# -> 1052 self.send(msg)
#    1054 if message_body is not None:
#    1055
#    1056     # create a consistent interface to message_body
#    1057     if hasattr(message_body, 'read'):
#    1058         # Let file-like take precedence over byte-like.  This
#    1059         # is needed to allow the current position of mmap'ed
#    1060         # files to be taken into account.
#
# File c:\Users\iwuba\AppData\Local\Programs\Python\Python311\Lib\http\client.py:990, in HTTPConnection.send(self, data)
#     988 if self.sock is None:
#     989     if self.auto_open:
# --> 990         self.connect()
#     991     else:
#     992         raise NotConnected()
#
# File c:\Users\iwuba\AppData\Local\Programs\Python\Python311\Lib\http\client.py:956, in HTTPConnection.connect(self)
#     954 """Connect to the host and port specified in __init__."""
#     955 sys.audit("http.client.connect", self, self.host, self.port)
# --> 956 self.sock = self._create_connection(
#     957     (self.host,self.port), self.timeout, self.source_address)
#     958 # Might fail in OSs that don't implement TCP_NODELAY
#     959 try:
#
# File c:\Users\iwuba\AppData\Local\Programs\Python\Python311\Lib\socket.py:843, in create_connection(address, timeout, source_address, all_errors)
#     841 except error as exc:
#     842     if not all_errors:
# --> 843         exceptions.clear()  # raise only the last error
#     844     exceptions.append(exc)
#     845     if sock is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# Since we wouldn't know in advance how much data there is and how many times we need to click the button, we have to use the functions of the library to understand when the button is disabled.

# %%
with Driver() as driver:
    driver.open(newURL)
    button_selector = "#add-btn" # the id attribute value for the button
    driver.sleep(1)
    while not driver.is_attribute_present(button_selector, "disabled"):
        driver.click(button_selector)
        driver.sleep(1)
        
    # this line needs to be withing the "with ... as ..." block
    rendered_html = driver.get_page_source()

# %% [markdown]
# Let's check that we got all the data by calling the scraping function:

# %%
parse_table(rendered_html)
# Out:
# [('Student ID', 'Name', 'Grade'),
#  ('201', 'Diana Prince', 'A+'),
#  ('202', 'Evan Wright', 'B+'),
#  ('203', 'Fiona Gallagher', 'A'),
#  ('204', 'George Clark', 'B'),
#  ('205', 'Hannah Abbott', 'A-'),
#  ('206', 'Ian Malcolm', 'A'),
#  ('207', 'Julia Roberts', 'B+'),
#  ('208', 'Kevin Bacon', 'A+'),
#  ('209', 'Laura Croft', 'A-')]

# %% [markdown]
# <a id="sec4"></a>
#
# ## 4. Scrolling with `seleniumbase`
#
# Very often, the server will only serve a portion of the page and then load more of the content based on user actions such as scrolling. In fact, most of the web today is based on the concept of "infinite scrolling", new content keeps showing up as you scroll down a page.
#
# Seleniumbase makes it very easy to load the content that is updated dynamically while scrolling.
#
# We will test this with our [infinte_dramas.html](https://cs.wellesley.edu/~cs315/scraping/infinite_dramas.html) page (although it's not infinite).
#
# First we will simply get the page to see what's there:

# %%
from seleniumbase import Driver

url = "https://cs.wellesley.edu/~cs315/scraping/infinite_dramas.html"

with Driver() as driver:
    driver.open(url)
    driver.sleep(1)
    rendered_html = driver.get_page_source()

# %% [markdown]
# Let's write a few lines of BeautifulSoup to see how many dramas are there:

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(rendered_html, "html.parser")
cards = soup.find_all("div", class_="drama-card")
print(len(cards))
# Out:
# 3

# %% [markdown]
# As expected, we got the 3 dramas that show in the page at the start. Now we need to **simulate** scrolling in order to ge the rest of the dramas show up.

# %%
from seleniumbase import Driver

url = "https://cs.wellesley.edu/~cs315/scraping/infinite_dramas.html"

with Driver() as driver:
    driver.open(url)
    driver.sleep(1)
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    driver.sleep(1)
    rendered_html = driver.get_page_source()

# %% [markdown]
# Let's check again how many "drama cards" are received:

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(rendered_html, "html.parser")
cards = soup.find_all("div", class_="drama-card")
print(len(cards))
# Out:
# 15

# %% [markdown]
# We know that there are more than 6 dramas, so we need to have a loop that keeps scrolling. That means that we need to use the scraping capabilities of selenium to check on the fly for the number of drama cards.
#
# **Note:** This example is an excellent one for showing where the looping construct `while` instead of `for` is needed. We have to keep scrolling until we read the end and then break out of the loop.

# %%
from seleniumbase import Driver

url = "https://cs.wellesley.edu/~cs315/scraping/infinite_dramas.html"

last_count = 0

with Driver() as driver:
    driver.open(url)

    while True:
        # 1. Scroll to the bottom of the page using JavaScript
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        
        # 2. Wait for dynamic JavaScript content to render
        driver.sleep(1.0)
        
        # 3. Check the new count of target elements
        current_count = len(driver.find_elements(".drama-card"))
        print(f"Drama count: {current_count}")
        
        # 4. Exit the loop if no new items loaded after scrolling
        if current_count == last_count:
            print("Reached the bottom of the page.")
            break
            
        last_count = current_count
# Out:
# Drama count: 6
# Drama count: 9
# Drama count: 12
# Drama count: 15
# Drama count: 15
# Reached the bottom of the page.

# %% [markdown]
# need to get html saved in order to parse in part 5!!!!!!!!!!!!!!!!!

# %% [markdown]
# <a id="sec5"></a>
#
# ## 5. Your Task: Write a simple parser
#
# Now that we were able to get the list of all dramas from our Top Dramas page, **write a function** similar to function `parse_table` above to exract the following fields from each drama card:
#
# ```
# {rank: "#6",
# title: "Alchemy of Souls",
# year: "2022",
# eps: "20 episodes",
# rating: "8.9",
# type: "Korean Drama",
# synopsis: "A powerful sorceress in a blind woman's body encounters a man from a prestigious family..." }
# ```

# %%
def parse_drama(html_content):
    """
    create a parsing table that will parse information from the HTML and process it to get data
    """

# %% [markdown]
# parse table code from above:
# def parse_table(html_content):
#     """Parses HTML content and returns table rows as a list of tuples."""
#     if not html_content:
#         return []
#
#     soup = BeautifulSoup(html_content, "html.parser")
#     rows = soup.find_all("tr")
#
#     table_data = []
#     for row in rows:
#         cells = [cell.get_text(strip=True) for cell in row.find_all(["th", "td"])] #table header or table data
#         if cells:
#             table_data.append(tuple(cells)) #append to list
#
#     return table_data

# %% [markdown]
# Once you have your function, call it on the html content of scrolled page and then save the list of dictionaries into a JSON file, `scraping_results.json`.

# %% [markdown]
# <a id="sec6"></a>
#
# ## 6. Handling Pagination
#
# Our [mockup drama page](https://cs.wellesley.edu/~cs315/scraping/pagination-mockup.html) uses a pagination format, where the URL encodes the index of the page to visit, for example:
#
# ```
# https://cs.wellesley.edu/~cs315/scraping/pagination-mockup.html?page=4
# ```
#
# Below we show some sample code how to handle pagination.

# %%
import math
from seleniumbase import Driver

url = "https://cs.wellesley.edu/~cs315/scraping/pagination-mockup.html"

with Driver() as driver:
    driver.open(url)

    # 1. Extract total results count (e.g., "105 results" -> 105)
    total_text = driver.get_text("p.pull-right") # This will be a string value
    total_results = int(total_text.split()[0])

    # 2. Calculate total pages (20 items per page)
    total_pages = math.ceil(total_results / 20)
    print(f"Total results: {total_results} | Total pages: {total_pages}")

    # 4. Loop through each page URL
    for page in range(1, total_pages + 1):
        driver.open(f"{url}?page={page}")
        driver.sleep(1.0)

        # 5. Extract items on the current page
        cards = driver.find_elements(".box")
        print(f"Page {page}: Scraped {len(cards)} dramas")
# Out:
# Total results: 105 | Total pages: 6
# Page 1: Scraped 20 dramas
# Page 2: Scraped 20 dramas
# Page 3: Scraped 20 dramas
# Page 4: Scraped 20 dramas
# Page 5: Scraped 20 dramas
# Page 6: Scraped 5 dramas

# %% [markdown]
# <a id="sec7"></a>
#
# ## 7. Your Task: Modify Parser
#
# You wrote a `parse_drama` function in Section 5. Update that function to extract the information from the `.box` elements in our paginated mockup drama page. Then calle that function within the loop from Section 6 to scrape the content of each drama and save everything into a JSON file.
